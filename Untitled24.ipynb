# %% [markdown]
# <a href="https://colab.research.google.com/github/hindia-vic/hyper_parameter_Tuning/blob/main/Untitled24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
import numpy as np

# %%
df=load_iris()
data=pd.DataFrame(df.data,columns=df.feature_names)
data['target']=df.target
data.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
data['target'] = data['target'].apply(lambda x: df.target_names[x])
data[47:150]
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 47                 4.6               3.2                1.4               0.2
# 48                 5.3               3.7                1.5               0.2
# 49                 5.0               3.3                1.4               0.2
# 50                 7.0               3.2                4.7               1.4
# 51                 6.4               3.2                4.5               1.5
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#          target
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.data, df.target, test_size=0.3)

# %%
from sklearn.svm import SVC
model = SVC(kernel='rbf',C=30,gamma='auto')
model.fit(X_train, y_train)
# Out:
# SVC(C=30, gamma='auto')

# %%
model.score(X_test, y_test)
# Out:
# 0.9777777777777777

# %%
#using kFold validation
from sklearn.model_selection import cross_val_score
cross_val_score(SVC(kernel='linear',C=10,gamma='auto'),df.data, df.target, cv=5)
# Out:
# array([1.        , 1.        , 0.9       , 0.96666667, 1.        ])

# %%
cross_val_score(SVC(kernel='rbf',C=10,gamma='auto'),df.data, df.target, cv=5)
# Out:
# array([0.96666667, 1.        , 0.96666667, 0.96666667, 1.        ])

# %%
cross_val_score(SVC(kernel='rbf',C=20,gamma='auto'),df.data, df.target, cv=5)
# Out:
# array([0.96666667, 1.        , 0.9       , 0.96666667, 1.        ])

# %%
#performing it using loop
kernels = ['rbf', 'linear']
C = [1,10,20]
avg_scores = {}
for kval in kernels:
    for cval in C:
        cv_scores = cross_val_score(SVC(kernel=kval,C=cval,gamma='auto'),df.data, df.target, cv=5)
        avg_scores[kval + '_' + str(cval)] = np.average(cv_scores)

avg_scores
# Out:
# {'rbf_1': 0.9800000000000001,
#  'rbf_10': 0.9800000000000001,
#  'rbf_20': 0.9666666666666668,
#  'linear_1': 0.9800000000000001,
#  'linear_10': 0.9733333333333334,
#  'linear_20': 0.9666666666666666}

# %%
from sklearn.model_selection import GridSearchCV
clf = GridSearchCV(SVC(gamma='auto'), {
    'C': [1,10,20],
    'kernel': ['rbf','linear']
}, cv=5, return_train_score=False)
clf.fit(df.data, df.target)
clf.cv_results_
# Out:
# {'mean_fit_time': array([0.00121217, 0.00079803, 0.00094109, 0.00079846, 0.00087118,
#         0.00079732]),
#  'std_fit_time': array([4.35055321e-04, 3.27092217e-05, 1.38882897e-04, 5.37012644e-05,
#         4.13280572e-05, 5.30937138e-05]),
#  'mean_score_time': array([0.00079484, 0.00057564, 0.00059175, 0.00056429, 0.00065494,
#         0.0005496 ]),
#  'std_score_time': array([2.68186054e-04, 6.86239083e-05, 2.42043594e-05, 3.99720391e-05,
#         1.35642949e-04, 1.96115187e-05]),
#  'param_C': masked_array(data=[1, 1, 10, 10, 20, 20],
#               mask=[False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_kernel': masked_array(data=['rbf', 'linear', 'rbf', 'linear', 'rbf', 'linear'],
#               mask=[False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'C': 1, 'kernel': 'rbf'},
#   {'C': 1, 'kernel': 'linear'},
#   {'C': 10, 'kernel': 'rbf'},
# ...

# %%
#converting the result above to dataframe
result = pd.DataFrame(clf.cv_results_)
result
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0       0.001212      0.000435         0.000795        0.000268       1
# 1       0.000798      0.000033         0.000576        0.000069       1
# 2       0.000941      0.000139         0.000592        0.000024      10
# 3       0.000798      0.000054         0.000564        0.000040      10
# 4       0.000871      0.000041         0.000655        0.000136      20
# 5       0.000797      0.000053         0.000550        0.000020      20
#
#   param_kernel                         params  split0_test_score  \
# 0          rbf      {'C': 1, 'kernel': 'rbf'}           0.966667
# 1       linear   {'C': 1, 'kernel': 'linear'}           0.966667
# 2          rbf     {'C': 10, 'kernel': 'rbf'}           0.966667
# 3       linear  {'C': 10, 'kernel': 'linear'}           1.000000
# 4          rbf     {'C': 20, 'kernel': 'rbf'}           0.966667
# 5       linear  {'C': 20, 'kernel': 'linear'}           1.000000
#
# ...

# %%
#viewing  important detail from above dataframe
result[['param_C','param_kernel','mean_test_score']]
# Out:
#   param_C param_kernel  mean_test_score
# 0       1          rbf         0.980000
# 1       1       linear         0.980000
# 2      10          rbf         0.980000
# 3      10       linear         0.973333
# 4      20          rbf         0.966667
# 5      20       linear         0.966667

# %%
#implementimnh randomizedsearchCSV
from sklearn.model_selection import RandomizedSearchCV
rs = RandomizedSearchCV(SVC(gamma='auto'), {
        'C': [1,10,20],
        'kernel': ['rbf','linear']
    },
    cv=5,
    return_train_score=False,
    n_iter=2
)
rs.fit(df.data, df.target)
pd.DataFrame(rs.cv_results_)[['param_C','param_kernel','mean_test_score']]
# Out:
#   param_C param_kernel  mean_test_score
# 0       1       linear         0.980000
# 1      20          rbf         0.966667

# %%
#trying different hyperparameter from different model
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto'),
        'params' : {
            'C': [1,10,20],
            'kernel': ['rbf','linear']
        }
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'C': [1,5,10]
        }
    }
}

# %%
scores = []

for model_name, mp in model_params.items():
    clf =  GridSearchCV(mp['model'], mp['params'], cv=5, return_train_score=False)
    clf.fit(df.data, df.target)
    scores.append({
        'model': model_name,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })

df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score                best_params
# 0                  svm    0.980000  {'C': 1, 'kernel': 'rbf'}
# 1        random_forest    0.960000       {'n_estimators': 10}
# 2  logistic_regression    0.966667                   {'C': 5}
